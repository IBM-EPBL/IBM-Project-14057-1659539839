# %% [markdown]
# ##IBM ASSIGNMENT 3
# ##Sriram K
# ##711619104048

# %% [markdown]
# ## Exercises
#
# Answer the questions or complete the tasks outlined in bold below, use the specific method described if applicable.

# %% [markdown]
# ** What is 7 to the power of 4?**

# %%
7**4
# Out:
# 2401

# %% [markdown]
# ** Split this string:**
#
#     s = "Hi there Sam!"
#
# **into a list. **

# %%
s = "Hi there Sam!"

# %%
x = s.split()
print(x)
# Out:
# ['Hi', 'there', 'Sam!']

# %% [markdown]
# ** Given the variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# ** Use .format() to print the following string: **
#
#     The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
print("The diameter of {planet} is {diameter} kilometres.".format)
# Out:
# <built-in method format of str object at 0x7f6f05814960>

# %% [markdown]
# ** Given this nested list, use indexing to grab the word "hello" **

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
print(lst[3][1][2])
# Out:
# ['hello']

# %% [markdown]
# ** Given this nest dictionary grab the word "hello". Be prepared, this will be annoying/tricky **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# ** What is the main difference between a tuple and a list? **

# %%
print("List is Mutable")
list = [1, 5, 6, 4, 67, 5]
print("Original list ", list)
list[3] = 77
print("Mutable ", list)


print("Tuple is immutable")
tup = (0, 1, 2, 3)
tup[0] = 4
#The value cannot be assigned 
print(tup)
# Out:
# List is Mutable
# Original list  [1, 2, 4, 4, 3, 3, 3, 6, 5]
# Mutable  [1, 2, 4, 77, 3, 3, 3, 6, 5]
# Tuple is immutable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-cd3ed6edc622> in <module>
#       8 print("Tuple is immutable")
#       9 tup = (0, 1, 2, 3)
# ---> 10 tup[0] = 4
#      11 print(tup)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ** Create a function that grabs the email website domain from a string in the form: **
#
#     user@domain.com
#
# **So for example, passing "user@domain.com" would return: domain.com**

# %%
def get_dom(mail):
 return(mail.split('@')[1])

# %%
mail = "user@domain.com"
get_dom(mail)
# Out:
# 'domain.com'

# %% [markdown]
# ** Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization. **

# %%
def get_dog(str):
 return("Dog" in str)

# %%
str="Dog is faithful animal"
get_dog(str)
# Out:
# True

# %% [markdown]
# ** Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases. **

# %%
def count_dog(str):
 return(str.count("dog"))

# %%
str = "The dog is a domesticated descendant of the wolf. Also called the domestic dog"
count_dog(str)
# Out:
# 2

# %% [markdown]
# ### Problem
# **You are driving a little too fast, and a police officer stops you. Write a function
#   to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket".
#   If your speed is 60 or less, the result is "No Ticket". If speed is between 61
#   and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big    Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all
#   cases. **

# %%
def caught_speeding(speed, is_birthday):
    
    if is_birthday:
        speeding = speed - 5
    else:
        speeding = speed
    
    if speeding > 80:
        return 'Big Ticket'
    elif speeding > 60:
        return 'Small Ticket'
    else:
        return 'No Ticket'

# %%
caught_speeding(95,True)
# Out:
# 'Big Ticket'

# %%
caught_speeding(75,False)
# Out:
# 'Small Ticket'

# %% [markdown]
# Create an employee list with basic salary values(at least 5 values for 5 employees)  and using a for loop retreive each employee salary and calculate total salary expenditure.

# %%
emp_sal=[64000,87000,65000,12000,13000]
x=0
for i in emp_sal:
 x=x+i
 print("Employee Salary",i)
print("Total Expenditure for Salary",x)
# Out:
# Employee Salary 64000
# Employee Salary 87000
# Employee Salary 65000
# Employee Salary 12000
# Employee Salary 13000
# Total Expenditure for Salary 241000

# %% [markdown]
# Create two dictionaries in Python:
#
# First one to contain fields as Empid,  Empname,  Basicpay
#
# Second dictionary to contain fields as DeptName,  DeptId.
#
# Combine both dictionaries.

# %%
dict1={'Empid':'KX001','Empname':'Mr.Minak', 'Basicpay':'54600PM'}
dict2={'DeptName':'HR','DeptId':'32'}
dict2.update(dict1)
print(dict2)
# Out:
# {'DeptName': 'HR', 'DeptId': '32', 'Empid': 'KX001', 'Empname': 'Mr.Minak', 'Basicpay': '54600PM'}
